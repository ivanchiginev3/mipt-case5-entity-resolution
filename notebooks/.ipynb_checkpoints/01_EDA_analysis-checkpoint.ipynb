# %% [markdown]
# # EDA для задачи ENTITY RESOLUTION

# %% [markdown]
# ## 1. Основная информация о датасете

# %% [markdown]
# ### Hackathon Dataset
#
# Это набор для задачи по entity resolution в compliance-контексте.

# %% [markdown]
# #### Файл
#
# - `student_relations.parquet` — основная таблица для работы
# - `summary.json` — краткая статистика по итоговой выборке.
#
# Одна строка в `student_relations.parquet` — это связь между компанией и связанным субъектом.
#
# Примеры:
# - компания и директор
# - компания и владелец / участник
# - компания и иное связанное лицо

# %% [markdown]
# #### Поля
#
# - `record_id` — технический идентификатор строки
# - `country` — страна источника
# - `source_snapshot_date` — дата снапшота / дата фиксации записи
# - `relation_kind` — общий тип связи, например `director` или `shareholder`
# - `relation_role` — более конкретная роль из источника
# - `party_type` — тип связанного субъекта, если он известен
# - `company_public_id` — обезличенный идентификатор компании
# - `company_name_norm` — нормализованное название компании
# - `party_public_id` — обезличенный идентификатор субъекта, если он был доступен в источнике
# - `party_name` — имя / наименование связанного субъекта в исходном источнике
# - `ownership_share_pct` — доля владения, если она известна

# %% [markdown]
# #### Что можно решать
#
# Основные задачи:
# - дедупликация записей о людях и компаниях
# - поиск совпадений для новой записи
# - cross-country matching
# - поиск случаев, где одна и та же сущность встречается в разных ролях и странах
#
# Хорошие baseline-задачи:
# - person-to-person matching по именам
# - company-to-company matching по `company_name_norm`
# - ranking top-K похожих записей
# - clustering дублей

# %% [markdown]
# #### Что можно линковать с чем
#
# Полезные типы сопоставления:
# - `party_name` ↔ `party_name`
# - `company_name_norm` ↔ `company_name_norm`
# - `party_name` ↔ `company_name_norm`
#
# Последний случай важен, потому что в части стран локальная компания может встретиться на стороне связанного субъекта, а не только как целевая компания в строке.
#
# Дополнительные сигналы:
# - `country`
# - `relation_kind`
# - `relation_role`
# - `source_snapshot_date`
# - `ownership_share_pct`

# %% [markdown]
# #### Ограничения и важные нюансы
#
# - Реальные `tax_id` / `inn` / `voen` в студенческом датасете заменены на детерминированные surrogate key.
# - `company_public_id` и `party_public_id` стабильны внутри выдачи, но не раскрывают исходный идентификатор.
# - В текущую учебную выборку входят `arm`, `azb`, `kaz`, `kgz`, `mng`, `tjk`.
# - `uzb` намеренно исключён из student-facing пакета, чтобы не раздувать объём и не ухудшать качество задач за счёт шумного exact matching.

# %% [markdown]
# #### Связь с брифом
#
# Этот датасет подходит для следующих задач из брифа:
# - дедупликация ФЛ и ЮЛ
# - fuzzy matching
# - мультиязычный matching
# - cross-country matching
# - построение search API и duplicate-check API
# - кластеризация дублей
# - оценка baseline и более сильных подходов

# %% [markdown]
# #### Размер набора
#
# Итоговые строки по странам:
#
# ```
# {
#   "arm": 472261,
#   "azb": 297747,
#   "kaz": 796553,
#   "kgz": 868689,
#   "mng": 1210633,
#   "tjk": 87364
# }
# ```

# %% [markdown]
# ## 2. Необходимые импорты

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from transliterate import translit
import re
import json
import os

# %% [markdown]
# ## 3. Первичный осмотр данных

# %% [markdown]
# ### 3.1 Загрузка и базовая информация

# %%
DATASET_PATH = "student_relations.parquet"

# %%
df = pd.read_parquet(DATASET_PATH, engine='fastparquet')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3733247 entries, 0 to 3733246
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   record_id             object
#  1   country               object
#  2   source_snapshot_date  object
#  3   relation_kind         object
#  4   relation_role         object
#  5   party_type            object
#  6   company_public_id     object
#  7   company_name_norm     object
#  8   party_public_id       object
#  9   party_name            object
#  10  ownership_share_pct   float64
# dtypes: float64(1), object(10)
# memory usage: 313.3+ MB

# %% [markdown]
# **Выводы:** Датасет содержит 3 733 247 записей в 11 колонках. Из типов даных нужно поправить колонку `source_snapshot_date` с object на datetime. Датасет занимает 313 Мб

# %% [markdown]
# ### 3.2. Первывй взгляд на данные

# %% [markdown]
# Первые 5 записей

# %%
df.head()
# Out:
#                                   record_id country source_snapshot_date relation_kind     relation_role  party_type             company_public_id             company_name_norm party_public_id            party_name  ownership_share_pct
# 0  arm_rec_49df8429c4e1912e923f09210d5d2c39     arm           2023-01-09   shareholder  beneficial_owner  individual  arm_company_e8217b23afa28741                      արոմատոս            None      Անդրանիկ Աբարյան                100.0
# 1  arm_rec_ee7466e19e5683c426051f8f94e13930     arm           2024-02-06   shareholder  beneficial_owner  individual  arm_company_997ee60051c4fda1           տրապիզոն քոնսթրաքշն            None  Տիգրան Հարությունյան                 50.0
# 2  arm_rec_344e2597b9b2d65611c3ea6689aeb786     arm           2022-03-02   shareholder  beneficial_owner  individual  arm_company_ba593702ed7d5006       անհայտ կազմակերպություն            None       Նարեկ Նարգիզյան                 30.0
# 3  arm_rec_bb45f92e3f36dcbedeb82569d875a6f9     arm           2024-01-18   shareholder  beneficial_owner  individual  arm_company_dbdf69c5afa462f3  լեոն ա յակուբյան քոնթրաքթինգ            None      ՎԱՍԿԵՆ ՅԱԿՈՒԲՅԱՆ                100.0
# 4  arm_rec_d4ffbf80b5b31e075113302d085b674f     arm           2024-01-30   shareholder  beneficial_owner  individual  arm_company_f39e74b9a9df4d74                  սանտաֆամիլիա            None        Ժիրայր Ավանյան                 15.0

# %% [markdown]
# Последние 5 записей

# %%
df.tail()
# Out:
#         record_id country source_snapshot_date relation_kind relation_role  party_type             company_public_id company_name_norm             party_public_id party_name  ownership_share_pct
# 3733242      None     tjk           1546300800      director      director  individual  tjk_company_232d15ee9e46fd43              None  tjk_party_f556f4e0523cc391       None                  NaN
# 3733243      None     tjk           1546300800      director      director  individual  tjk_company_07ef7be724326416              None  tjk_party_890f935e3930016d       None                  NaN
# 3733244      None     tjk           1546300800      director      director  individual  tjk_company_73c34b8b58d5e276              None  tjk_party_4e5b60c494368d47       None                  NaN
# 3733245      None     tjk           1546300800      director      director  individual  tjk_company_5afc3b60b8f09b5b              None  tjk_party_52c6a14aab10ec67       None                  NaN
# 3733246      None     tjk           1546300800      director      director  individual  tjk_company_8d42f23036cad7ba              None  tjk_party_4c4034a3c7e1ad7d       None                  NaN

# %% [markdown]
# Случайная выборка из 10 записей

# %%
df.sample(n=10, random_state=42)
# Out:
#                                         record_id country source_snapshot_date relation_kind       relation_role  party_type             company_public_id                         company_name_norm party_public_id                         party_name  ownership_share_pct
# 3034024                                      None     mng           2026-01-11   shareholder         shareholder  individual  mng_company_a7d988de7820698f                         зэс эрдэнийн хувь            None                               None                  NaN
# 439061   arm_rec_987bea6e0a895dff3f0957861f16cc9c     arm           2024-02-15   shareholder    beneficial_owner  individual  arm_company_2af28ef7271c36f6                                 վմվ գրուպ            None                    Վարդան Գալստյան                 50.0
# 3639751                                      None     mng           2026-01-11           ubo                 ubo  individual  mng_company_5b765b60a4029aaa                        гэгээн эрхэт хараа            None                               None                  NaN
# 2116280  kgz_rec_bdcdb8c8379e471528b0eaa7dae52308     kgz           2022-02-15   shareholder             founder     unknown  kgz_company_a06a863f86b5008e  mohid international мохид интернэшнл жчк            None                   Малик Наим Ахмед                  NaN
# 1789927                                      None     kgz           2022-02-15   shareholder             founder     unknown  kgz_company_92f04f93be0795c0                                      None            None                               None                  NaN
# 2591462                                      None     mng           2026-01-11      director  Гүйцэтгэх  захирал  individual                          None                                      None            None                               None                  NaN
# 1402316  kaz_rec_b503378189583d29825fc8c1421da1dd     kaz           2025-12-04      director            director  individual  kaz_company_038b5bdd8f8755c7         сатыбалдиева перизат кыдырбеккызы            None  САТЫБАЛДИЕВА ПЕРИЗАТ КЫДЫРБЕККЫЗЫ                  NaN
# 2798687                                      None     mng           2026-01-11   shareholder         shareholder  individual  mng_company_c29ec1f96a27a190                               дархан онон            None                               None                  NaN
# 3313410  mng_rec_100a317621602f7fb1a7b3cab6a697b0     mng           2026-01-11   shareholder         shareholder  individual  mng_company_c4c693820bd0f2e2  зун мэн тианда эрчим уул уурхайн компани            None                      Yang Shuxiang                  NaN
# 745059                                       None     azb           2013-02-06      director            director  individual  azb_company_ff01b849827c9658                                      None            None                               None                  NaN

# %% [markdown]
# **Выводы:** Необходимо обратить внимание на мультиязычность датасета и пропуски в данных.

# %% [markdown]
# ### 3.3 Проверка целостности

# %%
df.isnull().sum()
# Out:
# record_id               1659119
# country                       0
# source_snapshot_date          0
# relation_kind                 0
# relation_role                 0
# party_type                    0
# company_public_id        480945
# company_name_norm       1575763
# party_public_id         3621106
# party_name              1515455
# ownership_share_pct     3435090
# dtype: int64

# %% [markdown]
# **Вывод:** Видим большое количество пропусков в некоторых полях, выполним более детальный анализ далее

# %% [markdown]
# ## 4. Анализ пропусков и качества данных

# %% [markdown]
# ### 4.1 Матрица пропусков

# %%
missing = pd.DataFrame({
    'Пропусков': df.isnull().sum(),
    'Процент': (df.isnull().sum() / len(df) * 100).round(2)
})

# Сортируем по убыванию
missing = missing.sort_values('Процент', ascending=False)

# %%
print(missing)
# Out:
#                       Пропусков  Процент
# party_public_id         3621106    97.00
# ownership_share_pct     3435090    92.01
# record_id               1659119    44.44
# company_name_norm       1575763    42.21
# party_name              1515455    40.59
# company_public_id        480945    12.88
# country                       0     0.00
# source_snapshot_date          0     0.00
# party_type                    0     0.00
# relation_kind                 0     0.00
# relation_role                 0     0.00

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Тепловая карта пропусков (желтый = пропуск)')
plt.xlabel('Поля')
plt.ylabel('Строки')
plt.show()

# %% [markdown]
# **Выводы:**
# 1. `party_public_id`. Как видно неразмеченных данных 97 процентов от всего датасета. Размеченных данных для обучения достаточно
# 2. `ownership_share_pct`. Второстепенный признак, не обязательный для baseline
# 3. `record_id`. Техническое поле, для модели можно проигнорировать
# 4. `company_name_norm`. Для связей `party_name` ↔ `company_name_norm` будет ограничение. Важное поле, но его отсутствие в 42% случаев нужно учитывать
# 5. `party_name`. Основное поле для матчинга, доступно в 60% случаев
# 6. `company_public_id`. Полезное поле, доступно в большинстве случаев

# %% [markdown]
# ### 4.2 Категоризация записей

# %%
data = []
for has_id in [True, False]:
    subset = df[df['party_public_id'].notna() == has_id]
    label = 'Размеченные' if has_id else 'Неразмеченные'
    total = len(subset)
    
    all_five = (subset['party_name'].notna() & 
                subset['company_name_norm'].notna() & 
                subset['record_id'].notna() & 
                subset['ownership_share_pct'].notna() & 
                subset['company_public_id'].notna())
    
    data.append({
        'Тип данных': label,
        'Всего записей': total,
        'Есть все 5 полей': round(all_five.sum() / total * 100, 2),
        'Есть party_name': round(subset['party_name'].notna().sum() / total * 100, 2),
        'Есть company_name_norm': round(subset['company_name_norm'].notna().sum() / total * 100, 2),
        'Есть record_id': round(subset['record_id'].notna().sum() / total * 100, 2),
        'Есть ownership_share_pct': round(subset['ownership_share_pct'].notna().sum() / total * 100, 2),
        'Есть company_public_id': round(subset['company_public_id'].notna().sum() / total * 100, 2)
    })

summary = pd.DataFrame(data)
summary = summary.set_index('Тип данных').T
print("Категоризация в процентах")
summary
# Out:
# Категоризация в процентах
# Тип данных                Размеченные  Неразмеченные
# Всего записей               112141.00     3621106.00
# Есть все 5 полей                 0.04           7.20
# Есть party_name                 79.68          58.78
# Есть company_name_norm          68.11          57.47
# Есть record_id                  65.07          55.26
# Есть ownership_share_pct         0.04           8.23
# Есть company_public_id          99.15          86.74

# %% [markdown]
# **Вывод:** Структура размеченных и неразмеченных данных сопоставима.
# 1. `party_name` — основное поле для матчинга. Заполнено на 80% в размеченных и на 59% в неразмеченных. Для обучения есть 89 тыс. записей с именами — этого достаточно.
#
# 2. `company_public_id` — лучший контекстный признак. Заполнен на 99% в размеченных и на 87% в неразмеченных. Можно использовать для проверки: если две записи привязаны к одной компании, шанс дубликата выше.
#
# 3. `company_name_norm` — полезное дополнение. Заполнено на 68% в размеченных и на 57% в неразмеченных. Важно для связей "человек — компания".
#
# 4. `record_id` — техническое поле, для модели не используется.
#
# 5. `ownership_share_pct` — в размеченных данных практически отсутствует (0.04%). Для baseline-модели игнорируем.

# %% [markdown]
# ## 5. Анализ категориальных признаков

# %% [markdown]
# ### 5.1 Анализ распределния по странам

# %%
# Распределение по странам (количество и %)
country_counts = df['country'].value_counts()
country_pct = (df['country'].value_counts(normalize=True) * 100).round(1)

print("СТРАНА  КОЛИЧЕСТВО  ПРОЦЕНТ")
for c in country_counts.index:
    print(f"{c:<7} {country_counts[c]:>10,}  {country_pct[c]:>6.1f}%")

# График
country_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Распределение записей по странам')
plt.xlabel('Страна')
plt.ylabel('Количество записей')
plt.xticks(rotation=0)
plt.show()

# Детали по каждой стране
print("\nДЕТАЛИ ПО СТРАНАМ:")
for c in country_counts.index:
    subset = df[df['country'] == c]
    print(f"\n{c}:")
    print(f"  Период: {subset['source_snapshot_date'].min()} — {subset['source_snapshot_date'].max()}")
    print(f"  Уникальных компаний: {subset['company_name_norm'].nunique():,}")
    print(f"  Уникальных имен: {subset['party_name'].nunique():,}")
# Out:
# СТРАНА  КОЛИЧЕСТВО  ПРОЦЕНТ
# mng      1,210,633    32.4%
# kgz        868,689    23.3%
# kaz        796,553    21.3%
# arm        472,261    12.7%
# azb        297,747     8.0%
# tjk         87,364     2.3%
# ДЕТАЛИ ПО СТРАНАМ:
#
# mng:
#   Период: 2026-01-11 — 2026-01-11
#   Уникальных компаний: 260,203
#   Уникальных имен: 533,137
#
# kgz:
#   Период: 2022-02-15 — 2026-01-03
#   Уникальных компаний: 125,071
#   Уникальных имен: 196,543
#
# kaz:
#   Период: 2024-10-04 — 2026-01-26
#   Уникальных компаний: 197,186
#   Уникальных имен: 290,834
#
# arm:
#   Период: 2021-02-18 — 2025-07-02
#   Уникальных компаний: 5,060
#   Уникальных имен: 5,643
#
# azb:
#   Период: 2006-07-28 — 2026-03-30
#   Уникальных компаний: 0
#   Уникальных имен: 154,938
#
# tjk:
#   Период: 1298937600 — 1664323200
#   Уникальных компаний: 24,653
#   Уникальных имен: 39,950

# %% [markdown]
# **Выводы:** В выводах посмотрим на аномалии:
# 1. Монголия (mng): Все записи за одну дату (2026-01-11) — возможно снапшот. 533 тыс. уникальных имен — больше всех
#
# 2. Армения (arm): Всего 5,060 компаний и 5,643 имен — очень мало уникальных сущностей. Много дубликатов
#
# 3. Азербайджан (azb): 0 уникальных компаний — вообще нет названий компаний. Есть только имена (154,938)
#
# 4. Таджикистан (tjk): Даты в Unix timestamp — нужно преобразовать. Самый маленький сегмент (2.3%)

# %% [markdown]
# ### 5.2 Анализ типов связей

# %%
print("ЧАСТОТА relation_kind:")
print(df['relation_kind'].value_counts())
print(f"\nУникальных значений: {df['relation_kind'].nunique()}")

print("\nРАСПРЕДЕЛЕНИЕ ПО СТРАНАМ:")
cross = pd.crosstab(df['country'], df['relation_kind'])
print(cross)

print("\nВ ПРОЦЕНТАХ ПО СТРАНЕ:")
cross_pct = pd.crosstab(df['country'], df['relation_kind'], normalize='index') * 100
print(cross_pct.round(1))
# Out:
# ЧАСТОТА relation_kind:
# relation_kind
# shareholder    1809749
# director       1595567
# ubo             327931
# Name: count, dtype: int64
#
# Уникальных значений: 3
#
# РАСПРЕДЕЛЕНИЕ ПО СТРАНАМ:
# relation_kind  director  shareholder     ubo
# country
# arm                   0       472261       0
# azb              297747            0       0
# kaz              796553            0       0
# kgz              199233       669456       0
# mng              247093       635609  327931
# tjk               54941        32423       0
#
# В ПРОЦЕНТАХ ПО СТРАНЕ:
# relation_kind  director  shareholder   ubo
# country
# arm                 0.0        100.0   0.0
# azb               100.0          0.0   0.0
# kaz               100.0          0.0   0.0
# kgz                22.9         77.1   0.0
# mng                20.4         52.5  27.1
# tjk                62.9         37.1   0.0

# %% [markdown]
# Выводы:
# - arm, azb, kaz — только один тип связи (бесполезен как признак)
#
# - kgz, mng, tjk — есть микс, можно использовать как слабый признак
#
# - ubo встречается только в Монголии — для других стран не применим
#
# `relation_kind` можно использовать как контекст, но не как ключевой признак для матчинга

# %% [markdown]
# ### 5.3 Анализ более конкретных ролей

# %%
# Топ-20 ролей — столбчатая диаграмма
top_roles = df['relation_role'].value_counts().head(20)

plt.figure(figsize=(12, 6))
top_roles.plot(kind='bar', color='lightcoral', edgecolor='black')
plt.title('Топ-20 ролей (relation_role)')
plt.xlabel('Роль')
plt.ylabel('Количество записей')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# По странам
print("\nТОП-5 РОЛЕЙ ПО СТРАНАМ:")
for c in df['country'].unique():
    print(f"\n{c}:")
    print(df[df['country']==c]['relation_role'].value_counts().head(5))
# Out:
# ТОП-5 РОЛЕЙ ПО СТРАНАМ:
#
# arm:
# relation_role
# beneficial_owner    472261
# Name: count, dtype: int64
#
# azb:
# relation_role
# director    297747
# Name: count, dtype: int64
#
# kaz:
# relation_role
# director    796553
# Name: count, dtype: int64
#
# kgz:
# relation_role
# founder     669456
# director    199233
# Name: count, dtype: int64
#
# mng:
# relation_role
# shareholder           635609
# ubo                   327931
# Гүйцэтгэх  захирал    121198
# Захирал                73927
# Гүйцэтгэх захирал      40573
# Name: count, dtype: int64
#
# tjk:
# relation_role
# director       54941
# shareholder    32423
# Name: count, dtype: int64

# %% [markdown]
# **Вывод:** mng — единственная страна с разнообразием ролей, включая роли на монгольском языке. `relation_role` не ключевой признак для baseline

# %% [markdown]
# ### 5.4 Анализ типов субъектов

# %%
# Создаем subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Распределение party_type
df['party_type'].value_counts().plot(kind='bar', ax=axes[0], color='teal', edgecolor='black')
axes[0].set_title('Распределение party_type')
axes[0].set_xlabel('Тип субъекта')
axes[0].set_ylabel('Количество')
axes[0].tick_params(axis='x', rotation=0)

# 2. По странам
pd.crosstab(df['country'], df['party_type']).plot(kind='bar', stacked=True, ax=axes[1])
axes[1].set_title('party_type по странам')
axes[1].set_xlabel('Страна')
axes[1].set_ylabel('Количество')
axes[1].legend(title='party_type')
axes[1].tick_params(axis='x', rotation=0)

# 3. Связь с relation_kind
pd.crosstab(df['party_type'], df['relation_kind']).plot(kind='bar', stacked=True, ax=axes[2])
axes[2].set_title('party_type vs relation_kind')
axes[2].set_xlabel('party_type')
axes[2].set_ylabel('Количество')
axes[2].legend(title='relation_kind')
axes[2].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод**: `party_type` полезен для различения ФЛ и ЮЛ. Если `party_type` = legal_entity → 100% shareholder. Если `party_type` = individual → любая роль. Можно использовать как слабый признак

# %% [markdown]
# ### 5.5 Общий вывод:

# %% [markdown]
# **Что полезно для модели:**
#
# `country` — важный признак. Правила транслитерации и алфавиты зависят от страны.
#
# `party_type` — полезен. Разделяет ФЛ и ЮЛ. legal_entity всегда shareholder.
#
# `company_public_id` — самый сильный контекстный признак. Заполнен на 99% в разметке.
#
# **Что бесполезно для baseline:**
#
# `relation_kind` — для arm, azb, kaz только один тип связи. Слабый признак.
#
# `relation_role` — для большинства стран одна роль. Только в mng есть разнообразие.
#
# `ownership_share_pct` — в размеченных данных почти отсутствует (0.04%).
#
# **Итого:**
#
# - Сильные признаки: party_name + country + company_public_id + party_type
# - Слабые признаки: relation_kind, relation_role
# - Игнорируем: ownership_share_pct, record_id

# %% [markdown]
# ## 6. Анализ текстовых данных

# %% [markdown]
# ### 6.1 Анализ имен

# %%
name_len = df['party_name'].dropna().str.len()

# Количество уникальных
print(f"Уникальных имен: {df['party_name'].nunique():,}")
print(f"Средняя длина: {name_len.mean():.1f}")
print(f"Мин длина: {name_len.min()}")
print(f"Макс длина: {name_len.max()}")

# Гистограмма
plt.figure(figsize=(10, 5))
plt.hist(name_len.clip(0, 110), bins=50, edgecolor='black', color='skyblue')
plt.title('Распределение длины имен')
plt.xlabel('Длина имени')
plt.ylabel('Количество')
plt.show()

# Топ-10 имен
print("\nТОП-10 ИМЕН:")
print(df['party_name'].value_counts().head(10))

# Аномально короткие (1-2 символа)
short = df[df['party_name'].str.len() <= 2]['party_name'].value_counts().head(10)
print("\nКОРОТКИЕ ИМЕНА (1-2 символа):")
print(short)

# Аномально длинные (100+симоволов)
long = df[df['party_name'].str.len() >= 100]['party_name'].value_counts().head(5)
print("\nДЛИННЫЕ ИМЕНА (100+ символов):")
print(long)
# Out:
# Уникальных имен: 1,220,966
# Средняя длина: 21.6
# Мин длина: 1
# Макс длина: 296
# ТОП-10 ИМЕН:
# party_name
# Անհայտ կազմակերպություն                                                      50737
# ՆԵՈ ՄԵՏԱԼՍ ՀՈԼԴԻՆԳ ԼԻՄԻԹԵԴ                                                   14496
# Միրզաազիզ Մուսախանով                                                         11003
# Սվետլանա Երշովա                                                               8870
# ԱՐԴՅՈՒՆԱԲԵՐԱԿԱՆ ԸՆԿԵՐՈՒԹՅՈՒՆ ԲԸ                                               8172
# ՊՐՈՄԻՇԼԵՆՆԱՅԱ ԿՈՄՊԱՆԻԱ                                                        5316
# ՆԵՈ ՄԵՏԱԼՍ ՀՈԼԴԻՆԳ ԼԻՄԻԹԵԴ բաժնետոմսերով սահմանափակ մասնավոր ընկերություն     3675
# ՖԱՅՐԲԸՐԴ ՄԵՆԵՋՄԵՆՏ ՍՊԸ                                                        2760
# Եվգենիա Վասիլեվա                                                              2714
# Իրինա Գորշկովա                                                                2714
# Name: count, dtype: int64
#
# КОРОТКИЕ ИМЕНА (1-2 символа):
# party_name
# Ли    5
# ЮП    5
# -     4
# ГП    4
# Лю    4
# Ив    4
# Ма    4
# Су    3
# Ву    3
# 38    2
# Name: count, dtype: int64
#
# ДЛИННЫЕ ИМЕНА (100+ символов):
# party_name
# Государственное предприятие "Кыргызавтожол" при Министерстве транспорта и коммуникаций Кыргызской Республики"                   14
# Государственное предприятие "Кыргызавтожол- Север" при Министерстве транспорта и коммуникаций Кыргызской Республики"            12
# Учреждение "Государственное агентство физической культуры и спорта при Кабинете Министров Кыргызской Республики"                12
# Государственное учреждение "Кадастр" при Службе земельных ресурсов при Министерстве сельского хозяйства                         11
# Учреждение «Государственное агентство по управлению государственным имуществом при Кабинете Министров Кыргызской Республики»    11
# Name: count, dtype: int64

# %% [markdown]
# **Вывод:** Из интересного можно выделить сокращения. Не ясно что они значат. Для модели потребуется нормализация к нижнему регистру ну и транслитерация. С короткими именами пока не ясно что делать.

# %% [markdown]
# ### 6.2 Анализ алфавитов и языков

# %%
def detect_alphabet(text):
    if pd.isna(text):
        return None
    text = str(text)
    if any('\u0530' <= c <= '\u058F' for c in text):
        return 'Armenian'
    if any('А' <= c <= 'я' or c in 'ЁёӐӑӖӗҪҫӲӳ' for c in text):
        return 'Cyrillic'
    if any('A' <= c <= 'z' for c in text):
        return 'Latin'
    return 'Other'

df['alphabet'] = df['party_name'].apply(detect_alphabet)

alpha_data = df['alphabet'].dropna()

# Графики
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

alpha_data.value_counts().plot(kind='bar', ax=axes[0], color='skyblue', edgecolor='black')
axes[0].set_title('Распределение по алфавитам')
axes[0].set_xlabel('Алфавит')
axes[0].set_ylabel('Количество')
axes[0].tick_params(axis='x', rotation=0)

pd.crosstab(df['country'], df['alphabet']).plot(kind='bar', stacked=True, ax=axes[1])
axes[1].set_title('Алфавиты по странам')
axes[1].set_xlabel('Страна')
axes[1].set_ylabel('Количество')
axes[1].legend(title='Алфавит')
axes[1].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %%
other
# Out:
#                                         record_id country source_snapshot_date relation_kind relation_role    party_type             company_public_id              company_name_norm party_public_id party_name  ownership_share_pct       category alphabet
# 603551   azb_rec_b493815cf79f0a6196bf141739976bc0     azb           2015-08-05      director      director    individual  azb_company_039fe15fd9df61cd                           None            None      . . .                  NaN  Средние (3/5)    Other
# 1569712  kgz_rec_fe7e587eb4a0e3cf646f4532002fe30e     kgz           2025-04-24      director      director    individual  kgz_company_81b189932de4b611                           None            None      - - -                  NaN  Средние (3/5)    Other
# 1601232  kgz_rec_6cdc5ec64b0ff7afba664fb87ec3021a     kgz           2024-09-24      director      director    individual  kgz_company_bfc074e6e5703ca1  жоопкерчилиги чектелген коому            None      . . .                  NaN  Средние (4/5)    Other
# 1606286  kgz_rec_e970ae180afa8bdedd91ac0a125474cc     kgz           2025-12-17      director      director    individual  kgz_company_05fb5e53cb172188                           None            None          -                  NaN  Средние (3/5)    Other
# 1652689  kgz_rec_516fbb557defcbd7725b973255c3cc12     kgz           2025-01-24      director      director    individual  kgz_company_05fb5e53cb172188                           None            None          -                  NaN  Средние (3/5)    Other
# ...                                           ...     ...                  ...           ...           ...           ...                           ...                            ...             ...        ...                  ...            ...      ...
# 2724465                                      None     mng           2026-01-11   shareholder   shareholder  legal_entity  mng_company_c1f3f2c093869b07          три ди келаида монгол            None          0                  NaN  Средние (3/5)    Other
# 2775374                                      None     mng           2026-01-11   shareholder   shareholder    individual  mng_company_e6398f1ed811e024                         цэмбэт            None        0 0                  NaN  Средние (3/5)    Other
# 2857657  mng_rec_de7aaa0eaef5bb2c138a023eeb9ae641     mng           2026-01-11   shareholder   shareholder    individual  mng_company_ec0b4075ad38ac95                            удз            None     000 00                  NaN  Средние (4/5)    Other
# 2970034  mng_rec_6284db04a6c953bc9dc4c76a78ad934f     mng           2026-01-11   shareholder   shareholder    individual  mng_company_eb88903f90e47a85                  техник импорт            None   000 0000                  NaN  Средние (4/5)    Other
# 2975459                                      None     mng           2026-01-11   shareholder   shareholder    individual  mng_company_3bb6ab3cfd2e8faf           монголфакторинг ббсб            None      00 00                  NaN  Средние (3/5)    Other
#
# [201 rows x 13 columns]

# %% [markdown]
# **Вывод:** В other странные симолы (точки, тире, нули).
#
# Для модели:
# - 3 основных алфавита: Armenian, Cyrillic, Latin
# - Нужна транслитерация: Armenian → Latin, Cyrillic → Latin
# - Other: можно игнорировать

# %% [markdown]
# ### 6.3 Анализ названий компаний

# %%
# Уникальные компании
print(f"Уникальных компаний: {df['company_name_norm'].nunique():,}")

# Длина названий
comp_len = df['company_name_norm'].dropna().str.len()
print(f"Средняя длина: {comp_len.mean():.1f}")
print(f"Мин: {comp_len.min()}, Макс: {comp_len.max()}")

# Гистограмма длины
plt.figure(figsize=(10, 5))
plt.hist(comp_len.clip(0, 150), bins=50, edgecolor='black', color='lightgreen')
plt.title('Распределение длины названий компаний')
plt.xlabel('Длина')
plt.ylabel('Количество')
plt.show()

# Топ-10 компаний
print("\nТОП-10 КОМПАНИЙ:")
print(df['company_name_norm'].value_counts().head(10))

# Юридические формы
forms = ['ООО', 'АО', 'ЗАО', 'ТОО', 'ИП', 'LTD', 'LLC', 'INC', 'CORP', 'L.L.C.', 'ОсОО', 'ГП', 'ЧП']
print("\nЮРИДИЧЕСКИЕ ФОРМЫ:")
for f in forms:
    count = df['company_name_norm'].str.contains(f, case=False, na=False).sum()
    if count > 0:
        print(f"  {f}: {count:,}")
# Out:
# Уникальных компаний: 611,990
# Средняя длина: 27.1
# Мин: 1, Макс: 359
# ТОП-10 КОМПАНИЙ:
# company_name_norm
# անհայտ կազմակերպություն                                                      123828
# зэс эрдэнийн хувь                                                             22585
# նեո մետալս հոլդինգ լիմիթեդ                                                    19106
# նեո մետալս հոլդինգ լիմիթեդ բաժնետոմսերով սահմանափակ մասնավոր ընկերություն      8905
# արդյունաբերական ընկերություն բը                                                8744
# ուրբանեվենտ պլյուս սպը                                                         7078
# պրոմիշլեննայա կոմպանիա                                                         5477
# ամփ հոլդինգս փբը                                                               5188
# коммерциялык банк кыргызстан ачык акционердик коомунун семетей филиалы         4291
# хаан банк                                                                      4144
# Name: count, dtype: int64
#
# ЮРИДИЧЕСКИЕ ФОРМЫ:
#   ООО: 607
#   АО: 1,777
#   ЗАО: 40
#   ТОО: 8,694
#   ИП: 10,237
#   LTD: 4,284
#   LLC: 127
#   INC: 461
#   CORP: 824
#   L.L.C.: 18
#   ОсОО: 1,185
#   ГП: 237
#   ЧП: 66

# %% [markdown]
# **Вывод:** Юридические формы можно нормализовать: ТОО ≈ ОсОО ≈ ООО ≈ LTD ≈ LLC

# %% [markdown]
# ### 6.4 Поиск патернов и аномалий

# %%
# Имена только из заглавных букв (среди непустых)
upper_mask = df['party_name'].dropna().str.match(r'^[А-ЯA-ZЁӐӖҪӲ\u0530-\u058F]+$')
print(f"Имен заглавными: {upper_mask.sum():,}")

# Имена с цифрами или спецсимволами
special_mask = df['party_name'].dropna().str.contains(r'[\d@#$%^&*+=/\\[\]{}|~<>]', na=False)
print(f"Имен с цифрами/спецсимволами: {special_mask.sum():,}")

# Короткие имена (1-2 символа)
short = df['party_name'].dropna()[df['party_name'].str.len() <= 2]
print(f"Коротких имен (1-2 символа): {len(short):,}")
print("\nПримеры коротких имен:")
print(short.value_counts().head(15))

# Одинаковые названия у разных компаний
# Группируем по company_name_norm, считаем уникальные company_public_id
dup_companies = df.dropna(subset=['company_name_norm', 'company_public_id'])\
                  .groupby('company_name_norm')['company_public_id'].nunique()
same_name_diff_id = dup_companies[dup_companies > 1]
print(f"\nОдинаковых названий у разных компаний: {len(same_name_diff_id):,}")
print("\nПримеры:")
print(same_name_diff_id.head(10))
# Out:
# Имен ЗАГЛАВНЫМИ: 1,602
# Имен с цифрами/спецсимволами: 34,323
# Коротких имен (1-2 символа): 67
#
# Примеры коротких имен:
# party_name
# Ли    5
# ЮП    5
# -     4
# ГП    4
# Лю    4
# Ив    4
# Ма    4
# Су    3
# Ву    3
# 38    2
# КХ    2
# Не    2
# Йи    2
# Лу    2
# Аз    2
# Name: count, dtype: int64
#
# Одинаковых названий у разных компаний: 4,986
#
# Примеры:
# company_name_norm
# 140 high school жауапкершілігі шектеулі серіктестігі                               2
# 777 group жауапкершілігі шектеулі серіктестігі                                     2
# 999                                                                                4
# No32 береке мектепке чейинки билим беруу уюмунун камкорчулары коомдук бирикмеси    2
# No32 кум шоро орто мектеби мекемеси                                                2
# ab holding ltd жеке компаниясы                                                     2
# adal                                                                               2
# adam                                                                               3
# ailin                                                                              2
# aim                                                                                2
# Name: company_public_id, dtype: int64

# %% [markdown]
# Выводы:
# - заглавные → lower() при нормализации
# - Одинаковые названия компаний - сложный кейс для matching: одинаковое название ≠ одна компания

# %% [markdown]
# ### 6.5 Общий вывод

# %% [markdown]
# **Что нужно сделать для baseline:**
#
# 1. Нормализация текста:
#    - Привести к нижнему регистру
#    - Удалить спецсимволы, цифры, точки, тире
#    - Убрать лишние пробелы
#
# 2. Транслитерация:
#
#    - Armenian → Latin
#    - Cyrillic → Latin
#    - Latin оставить как есть
#
# 3. Юридические формы:
#
#    - Нормализовать: ТОО ≈ ОсОО ≈ ООО ≈ LTD ≈ LLC → убрать или заменить на единый маркер
#    - Удалять из названий при сравнении
#
# 4. Сложные случаи (потом):
#
#    - Сокращения ("Ли", "ГП", "ЮП") — непонятно что значат
#    - Одинаковые названия у разных компаний — нужны негативные примеры в обучении
#    - Короткие имена (1-2 символа) — пока не трогаем

# %% [markdown]
# ## 7. Анализ размеченных данных

# %% [markdown]
# ### 7.1 Статистика размеченных данных

# %%
# Только размеченные
labeled = df[df['party_public_id'].notna()]

print(f"Записей с party_public_id: {len(labeled):,}")
print(f"Уникальных сущностей (ID): {labeled['party_public_id'].nunique():,}")

# Размеры кластеров
sizes = labeled.groupby('party_public_id').size()
print(f"\nСредний размер кластера: {sizes.mean():.2f}")
print(f"Медианный размер: {sizes.median():.0f}")
print(f"Максимальный размер: {sizes.max()}")

# Группировка для гистограммы
size_cats = sizes.apply(lambda x: '5+' if x >= 5 else str(x))
size_counts = size_cats.value_counts()
order = ['1', '2', '3', '4', '5+']
size_counts = size_counts.reindex(order)

print("\nКластеров по размерам:")
for k, v in size_counts.items():
    print(f"  Размер {k}: {v:,}")

# Гистограмма
plt.figure(figsize=(8, 5))
size_counts.plot(kind='bar', color='teal', edgecolor='black')
plt.title('Размеры кластеров')
plt.xlabel('Размер кластера')
plt.ylabel('Количество')
plt.xticks(rotation=0)
plt.show()
# Out:
# Записей с party_public_id: 112,141
# Уникальных сущностей (ID): 53,427
#
# Средний размер кластера: 2.10
# Медианный размер: 1
# Максимальный размер: 13783
#
# Кластеров по размерам:
#   Размер 1: 28,730
#   Размер 2: 18,212
#   Размер 3: 4,482
#   Размер 4: 1,432
#   Размер 5+: 571

# %%
# Отрицательные пары — берем по 1 записи из каждого кластера
# Берем только кластеры размера 2+ (чтобы сравнивать разных людей)
ids_with_dups = sizes[sizes >= 2].index

# По одной записи из каждого кластера
one_per_cluster = labeled[labeled['party_public_id'].isin(ids_with_dups)].drop_duplicates('party_public_id')

n = len(one_per_cluster)
total_neg_pairs = n * (n - 1) / 2

print(f"Кластеров размера 2+: {len(ids_with_dups):,}")
print(f"По 1 записи из каждого: {n:,}")
print(f"Всего отрицательных пар между ними: {total_neg_pairs:,.0f}")
print(f"Положительных пар: ~50,000")
print(f"Соотношение: 1 к {total_neg_pairs / 50000:.0f}")
# Out:
# Кластеров размера 2+: 24,697
# По 1 записи из каждого: 24,697
# Всего отрицательных пар между ними: 304,958,556
# Положительных пар: ~50,000
# Соотношение: 1 к 6099

# %% [markdown]
# **Выводы:**
# - 54% сущностей встречаются 1 раз — не с чем сравнивать для обучения
# - 34% кластеров размера 2 — основная база для создания пар (таргет = 1)
# - Кластеры 3+ — 12% — хорошие примеры вариаций имен
# - Гигантский кластер 13,783 — вероятно, "Неизвестная организация" или подобное
#
# **Для создания обучающих пар:**
# - Кластеры размера 1: бесполезны (не с чем создавать положительные пары)
# - Кластеры размера 2: 18,212 × 1 пара = 18,212 положительных пар
# - Кластеры размера 3: 4,482 × 3 пары = 13,446 пар
# - Кластеры размера 4:    1,432 × 6 пар      = 8,592
# - Для кластера размера 5+ будем брать 10 пар на кластер: 571 × 10 пар = 5,710
#
# Всего: ~45,000 положительных пар

# %% [markdown]
# ### 7.2 Анализ вариаций в кластерах

# %%
# Анализ вариаций внутри кластеров размера 2+
labeled = df[df['party_public_id'].notna()]
sizes = labeled.groupby('party_public_id').size()
dup_ids = sizes[sizes >= 2].index
dup_data = labeled[labeled['party_public_id'].isin(dup_ids)]

def analyze_cluster(group):
    return pd.Series({
        'unique_names': group['party_name'].nunique(),
        'unique_countries': group['country'].nunique(),
        'unique_relations': group['relation_kind'].nunique(),
        'unique_companies': group['company_name_norm'].nunique(),
    })

cluster_stats = dup_data.groupby('party_public_id').apply(analyze_cluster)

# Гистограммы с явными категориями
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Уникальные имена
name_counts = cluster_stats['unique_names'].value_counts().sort_index()
axes[0, 0].bar(name_counts.index.astype(str), name_counts.values, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Уникальных имен в кластере')
axes[0, 0].set_xlabel('Количество уникальных имен')
for i, v in enumerate(name_counts.values):
    axes[0, 0].text(i, v + 50, str(v), ha='center')

# Уникальные страны
country_counts = cluster_stats['unique_countries'].value_counts().sort_index()
axes[0, 1].bar(country_counts.index.astype(str), country_counts.values, color='lightgreen', edgecolor='black')
axes[0, 1].set_title('Уникальных стран в кластере')
for i, v in enumerate(country_counts.values):
    axes[0, 1].text(i, v + 50, str(v), ha='center')

# Уникальные relation_kind
rel_counts = cluster_stats['unique_relations'].value_counts().sort_index()
axes[1, 0].bar(rel_counts.index.astype(str), rel_counts.values, color='salmon', edgecolor='black')
axes[1, 0].set_title('Уникальных relation_kind в кластере')
for i, v in enumerate(rel_counts.values):
    axes[1, 0].text(i, v + 50, str(v), ha='center')

# Уникальные компании
comp_counts = cluster_stats['unique_companies'].value_counts().sort_index()
# Группируем 5+ через pd.concat
comp_clean = comp_counts.copy()
if len(comp_clean) > 5:
    over5 = comp_clean[5:].sum()
    comp_clean = pd.concat([comp_clean[:5], pd.Series({'5+': over5})])
axes[1, 1].bar(comp_clean.index.astype(str), comp_clean.values, color='plum', edgecolor='black')
axes[1, 1].set_title('Уникальных компаний в кластере')
for i, v in enumerate(comp_clean.values):
    axes[1, 1].text(i, v + 50, str(v), ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы:**
# 1. Имена почти не варьируются. Транслитерация и опечатки почти не встречаются в разметке. Это упрощает задачу для baseline, но усложняет для ML
# 2. Кросс-страновых связей нет. Признак `country` будет очень сильным
# 3. Тип связи часто меняется. `relation_kind` — хороший контекстный признак

# %% [markdown]
# ### 7.3 Типизация вариаций

# %%
# Найдем все кластеры с разными именами (их всего 12)
multi_name = cluster_stats[cluster_stats['unique_names'] > 1]
print(f"Всего кластеров с разными именами: {len(multi_name)}")

for cid in multi_name.index:
    names = dup_data[dup_data['party_public_id'] == cid]['party_name'].unique()
    print(f"\nID: {cid}")
    for n in names:
        print(f"  {n}")
# Out:
# Всего кластеров с разными именами: 12
#
# ID: arm_party_08c10e0c2e663101
#   ՊՐՈՄԻՇԼԵՆՆԱՅԱ ԿՈՄՊԱՆԻԱ
#   ԱՐԴՅՈՒՆԱԲԵՐԱԿԱՆ ԸՆԿԵՐՈՒԹՅՈՒՆ ԲԸ
#   Պրոմիշլեննայա կոմպանիա
#
# ID: arm_party_54db7bcf8f23be5d
#   «ՆԵՈ ՄԵՏԱԼՍ» ՍՊԸ
#   «ՆԵՈ ՄԵՏԱԼՍ»
#
# ID: arm_party_5c386a8f7cd9dfaf
#   «ԶԱՆԳԵԶՈՒՐ ՄԱՅՆԻՆԳ» ՍՊԸ
#   «ԶԱՆԳԵԶՈՒՐ ՄԱՅՆԻՆԳ»
#
# ID: arm_party_5e037f5ac852c3bf
#   ՈՒՐԲԱՆԵՎԵՆՏ ՊԼՅՈՒՍ ՍՊԸ
#   Ուրբանեվենտ Պլյուս ՍՊԸ
#
# ID: arm_party_6555697887fd6a3e
#   ՄԻԿՇԻՆ
#   «ՄԻԿՇԻՆ»
#
# ID: arm_party_9e0901689ff90734
#   «ԶԱՆԳԵԶՈՒՐԻ ՊՂՆՁԱՄՈԼԻԲԴԵՆԱՅԻՆ ԿՈՄԲԻՆԱՏ» ՓԲԸ
#   "Զանգեզուրի պղնձամոլիբդենային կոմբինատ" ՓԲԸ
#   «ԶԱՆԳԵԶՈՒՐԻ ՊՂՆՁԱՄՈԼԻԲԴԵՆԱՅԻՆ ԿՈՄԲԻՆԱՏ»
#
# ID: arm_party_a22eeccd27959921
#   «ՄՈՒՆ ՄԵԹԱԼՍ» ՓԲԸ
#   «ՄՈՒՆ ՄԵԹԱԼՍ»
#   ՄՈՒՆ ՄԵԹԱԼՍ
#
# ID: arm_party_abea8f0a66567aca
#   «ՄԱՍԿՕ ՄԱՅՆ»
#   «ՄԱՍԿՕ ՄԱՅՆ» ՓԲԸ
#
# ID: arm_party_ae9f9798299f0a7c
#   ԱՎԻԱՏԵԽՆԱԼՈԳԻԱ ԳԱՄ ՓԲԸ
#   ԱՎԻԱՏԵԽՆՈԼՈԳԻԱ  ԳԱՄ ՓԲԸ
#
# ID: arm_party_e37a0726e4bad216
#   «ՍԹԱՐ ԴԱՍԹ»
#   «ՍԹԱՐ ԴԱՍԹ» ՓԲԸ
#
# ID: arm_party_ecf2ba27d1eca9fc
#   «ԱՄՓ ՀՈԼԴԻՆԳ»
#   «ԱՄՓ ՀՈԼԴԻՆԳ» ՍՊԸ
#
# ID: arm_party_f9f19c440afc7cf6
#   «ՀՐԱԶԴԱՆԻ ԷՆԵՐԳԵՏԻԿ ԿԱԶՄԱԿԵՐՊՈՒԹՅՈՒՆ (ՀՐԱԶՋԷԿ)»
#   «Հրազդանի էներգետիկ կազմակերպություն (ՀրազՋԷԿ)»

# %% [markdown]
# **Вывод:** Все на армянском, в основном паттерны это регистр, кавычки, опечатки но их мало. Для модели потребуется аугментация

# %% [markdown]
# ### 7.4 Общий вывод

# %% [markdown]
# 1. Статистика:
#    - 112,141 запись, 53,427 уникальных сущностей
#    - 54% кластеров — размер 1 (бесполезны для обучения)
#    - ~50,000 положительных пар можно создать
#    - Гигантский кластер 13,783 — ограничим 10 парами
#
# 2. Вариативность
#    - Всего 12 кластеров с разными именами из 24,697
#    - Нет кросс-страновых связей, нет транслитерации
#    - Основные паттерны: регистр, кавычки
#    - Всё на армянском
#
# **Что это значит:**
# - Для baseline — задача простая (exact match + нормализация)
# - Для ML — нужна аугментация
# - `country` — сильный признак (всегда одинаковый в кластере)
# - `relation_kind` — полезный контекст (меняется в 78% кластеров)

# %% [markdown]
# ## 8. Временной анализ

# %% [markdown]
# ### 8.1 Анализ дат

# %%
# Преобразуем даты
df['date'] = pd.to_datetime(df['source_snapshot_date'], errors='coerce')

# Исправляем tjk — даты в Unix timestamp
tjk_mask = (df['country'] == 'tjk') & (df['date'].isna())
tjk_dates = pd.to_datetime(df.loc[tjk_mask, 'source_snapshot_date'].astype(float), unit='s', errors='coerce')
df.loc[tjk_mask, 'date'] = tjk_dates

print(f"Диапазон дат: {df['date'].min()} — {df['date'].max()}")
print(f"Пропущено дат: {df['date'].isna().sum():,}")

df['year'] = df['date'].dt.year
year_counts = df['year'].value_counts().sort_index()

# Гистограмма
plt.figure(figsize=(15, 5))
years_int = [int(y) for y in year_counts.index]
plt.bar(years_int, year_counts.values, color='teal', edgecolor='black')
plt.title('Распределение записей по годам')
plt.xlabel('Год')
plt.ylabel('Количество')
plt.xticks(years_int)
plt.show()
# Out:
# Диапазон дат: 2006-07-28 00:00:00 — 2026-03-30 00:00:00
# Пропущено дат: 0

# %% [markdown]
# **Вывод:** Распределение неравномерное, старых мало новых много (это хорошо).

# %% [markdown]
# ### 8.2 Связь времени и дубликатов

# %%
# Дубликаты по годам (размеченные)
labeled = df[df['party_public_id'].notna()]

# Дубликаты внутри кластеров — записи с одинаковым ID
dup_records = labeled[labeled.duplicated('party_public_id', keep=False)]

# Гистограмма
plt.figure(figsize=(10, 5))
years_int = [int(y) for y in year_dup.index]
plt.bar(years_int, year_dup.values, color='coral', edgecolor='black')
plt.title('Распределение дубликатов по годам')
plt.xlabel('Год')
plt.ylabel('Количество дубликатов')
plt.xticks(years_int)
plt.show()

# Одна сущность в разные даты
cluster_dates = labeled.groupby('party_public_id')['date'].agg(['min', 'max', 'nunique'])
cluster_dates['timespan_days'] = (cluster_dates['max'] - cluster_dates['min']).dt.days
multi_date = cluster_dates[cluster_dates['nunique'] > 1]

print(f"\nКластеров с 2+ разными датами: {len(multi_date):,} из {len(cluster_dates):,}")
print(f"Средний разброс дат: {multi_date['timespan_days'].mean():.0f} дней")
print(f"Максимальный разброс: {multi_date['timespan_days'].max():.0f} дней")
# Out:
# Кластеров с 2+ разными датами: 6,917 из 53,427
# Средний разброс дат: 825 дней
# Максимальный разброс: 4229 дней

# %% [markdown]
# **Вывод:** Большинство кластеров - это записи в одну дату, тоесть снапшоты. Дата может быть признаком запись за один ень вероятнее дубликаты. 2020 год наверное массовая выгрузка. Записи с большим разбросом интересный кейс для анализа. Ниже привден этот анализ

# %%
# Кластеры с максимальным разбросом дат
top_span = cluster_dates[cluster_dates['nunique'] > 1].nlargest(10, 'timespan_days')

print("Топ-5 кластеров с максимальным разбросом дат:")
for cid in top_span.index:
    cluster = labeled[labeled['party_public_id'] == cid]
    names = cluster['party_name'].unique()
    dates = sorted(cluster['date'].unique())
    span = (dates[-1] - dates[0]).days
    
    print(f"\nID: {cid}")
    print(f"  Разброс: {span} дней ({span/365:.1f} лет)")
    print(f"  Записей: {len(cluster)}")
    print(f"  Имена: {names[:3]}")
    print(f"  Даты: {dates[0].date()} — {dates[-1].date()}")
    print(f"  Страна: {cluster['country'].unique()[0]}")
# Out:
# Топ-5 кластеров с максимальным разбросом дат:
#
# ID: tjk_party_028414d54bf369a2
#   Разброс: 4229 дней (11.6 лет)
#   Записей: 4
#   Имена: ['Алимахмадов Алишер' None]
#   Даты: 2011-03-01 — 2022-09-28
#   Страна: tjk
#
# ID: tjk_party_9c08b79d784cd8d6
#   Разброс: 4229 дней (11.6 лет)
#   Записей: 7
#   Имена: ['Абдиев Кароматулло Азизуллоевич' None]
#   Даты: 2011-03-01 — 2022-09-28
#   Страна: tjk
#
# ID: tjk_party_a14f4e0ed97abb98
#   Разброс: 4229 дней (11.6 лет)
#   Записей: 4
#   Имена: ['Шарифов Шавкат Муминович' None]
#   Даты: 2011-03-01 — 2022-09-28
#   Страна: tjk
#
# ID: tjk_party_956eb977c9096ea2
#   Разброс: 3820 дней (10.5 лет)
#   Записей: 7
#   Имена: ['Акрамов Мансур Валиевич' None]
#   Даты: 2011-03-01 — 2021-08-15
#   Страна: tjk
#
# ID: tjk_party_032ae0a7ce928479
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 3
#   Имена: ['Эркая Мехмет Али' None]
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk
#
# ID: tjk_party_101ad1027525b95d
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 4
#   Имена: ['Мирзоев Раҳим Боронович' None]
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk
#
# ID: tjk_party_4f42dab4404d6384
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 4
#   Имена: [None 'Кабиров Авазхон Султонович']
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk
#
# ID: tjk_party_5d90f776f7c295f3
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 3
#   Имена: ['Мухташов Абдурахмон Мирович' None]
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk
#
# ID: tjk_party_e6d4c8fe1f6bff56
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 3
#   Имена: [None]
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk
#
# ID: tjk_party_e7b758637887f869
#   Разброс: 3468 дней (9.5 лет)
#   Записей: 2
#   Имена: [None]
#   Даты: 2011-03-01 — 2020-08-28
#   Страна: tjk

# %% [markdown]
# **Выводы:** Самый большой разброс у Таджикистана, вероятно потому что только по нему есть исторические данные.

# %% [markdown]
# ### 8.3 Общий вывод

# %% [markdown]
# 1. Данные:
#    - Диапазон: 2006–2026 (20 лет)
#    - Основной объем: 2022–2026 (2.4M из 3.7M записей)
#    - 2006–2021: старые данные, очень мало
#
# 2. Дубликаты и время:
#
#    - 87% кластеров — записи за одну дату (снапшоты)
#    - 13% кластеров — сущность появляется в разные даты (разброс до 11 лет)
#    - Таджикистан — единственная страна с длинной историей
#    - 2020 год — аномальный пик дубликатов (44 тыс.)
#
# 3. Для baseline:
#
#    - Дата НЕ нужна как признак
#    - Большой разброс дат не меняет сущность (тот же человек)
#    - Можно игнорировать время для простой модели
#
# 4. Для ML:
#
#    - Дата может помочь для различения тезок (разные люди в разное время)

# %% [markdown]
# ## 9. Анализ числовых данных

# %% [markdown]
# ### 9.1 Доли владения

# %%
# Доли владения
shares = df['ownership_share_pct'].dropna()

# Гистограмма
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(shares.clip(0, 100), bins=50, edgecolor='black', color='teal')
axes[0].set_title('Распределение долей (0-100%)')
axes[0].set_xlabel('%')
axes[0].set_ylabel('Количество')

axes[1].hist(shares[shares > 100], bins=50, edgecolor='black', color='coral')
axes[1].set_title('Аномалии (> 100%)')
axes[1].set_xlabel('%')

plt.tight_layout()
plt.show()

# В размеченных данных
shares_labeled = df[df['party_public_id'].notna()]['ownership_share_pct'].dropna()
print(f"\nВ размеченных данных: {len(shares_labeled):,}")
# Out:
# В размеченных данных: 50

# %%
# Доли владения
shares = df['ownership_share_pct'].dropna()

print(f"Заполнено: {len(shares):,} из {len(df):,} ({len(shares)/len(df)*100:.1f}%)")
print(f"Среднее: {shares.mean():.1f}")
print(f"Медиана: {shares.median():.1f}")
print(f"Мин: {shares.min()}")
print(f"Макс: {shares.max()}")

# Гистограмма
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(shares.clip(0, 100), bins=50, edgecolor='black', color='teal')
axes[0].set_title('Распределение долей (0-100%)')
axes[0].set_xlabel('%')
axes[0].set_ylabel('Количество')

axes[1].hist(shares[shares > 100], bins=50, edgecolor='black', color='coral')
axes[1].set_title('Аномалии (> 100%)')
axes[1].set_xlabel('%')

plt.tight_layout()
plt.show()

# В размеченных данных
shares_labeled = df[df['party_public_id'].notna()]['ownership_share_pct'].dropna()
print(f"\nВ размеченных данных: {len(shares_labeled):,} (бесполезно)")
# Out:
# Заполнено: 298,157 из 3,733,247 (8.0%)
# Среднее: 63.2
# Медиана: 50.0
# Мин: 0.0
# Макс: 100.0
#
# > 100%: 0
# = 100%: 116,163
# = 50%: 42,504
# = 25%: 11,885
# В размеченных данных: 50 (бесполезно)

# %% [markdown]
# **Вывод:** Для baseline бесполезный для ML можно будет использовать как ополнительный признак

# %% [markdown]
# ### 9.2 Связь с другими признаками

# %%
# Связь с другими признаками
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Доля vs relation_kind
df.boxplot(column='ownership_share_pct', by='relation_kind', ax=axes[0])
axes[0].set_title('Доля vs Тип связи')
axes[0].set_ylabel('%')
axes[0].set_xlabel('')

# Доля vs страна
df.boxplot(column='ownership_share_pct', by='country', ax=axes[1])
axes[1].set_title('Доля vs Страна')
axes[1].set_ylabel('%')
axes[1].set_xlabel('')

# Доля vs party_type
df.boxplot(column='ownership_share_pct', by='party_type', ax=axes[2])
axes[2].set_title('Доля vs Тип субъекта')
axes[2].set_ylabel('%')
axes[2].set_xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:** Доля есть только в тех запиясх где страна Армения и тип связи shareholder. Типа субъекта 2 individual и legal_entity

# %% [markdown]
# ### 9.3 Общий вывод

# %% [markdown]
# `ownership_share_pct` для baseline игнорируем. Если и добавлять — то только на этапе ML как дополнительный признак, когда он доступен

# %% [markdown]
# ## 10. Поиск сложных случаев

# %% [markdown]
# ### 10.1 Неоднозначные мэтчанги

# %%
# Одинаковые имена у разных party_public_id (тезки)
labeled = df[df['party_public_id'].notna() & df['party_name'].notna()]
name_counts = labeled.groupby('party_name')['party_public_id'].nunique()
same_name_diff_id = name_counts[name_counts > 1]

print(f"Имен с разными ID (тезки): {len(same_name_diff_id):,}")
print(f"Топ-10 самых частых тезок:")
print(same_name_diff_id.nlargest(10))

# Разные имена у одного party_public_id
id_counts = labeled.groupby('party_public_id')['party_name'].nunique()
diff_names_same_id = id_counts[id_counts > 1]

print(f"\nКластеров с разными именами: {len(diff_names_same_id):,}")

# Компании с одинаковыми названиями в разных странах
companies = df[df['company_name_norm'].notna()]
comp_country = companies.groupby('company_name_norm')['country'].nunique()
same_comp_diff_country = comp_country[comp_country > 1]

print(f"\nКомпаний в 2+ странах: {len(same_comp_diff_country):,}")
print("Примеры:")
print(same_comp_diff_country.head(10))
# Out:
# Имен с разными ID (тезки): 169
# Топ-10 самых частых тезок:
# party_name
# Азизов Ашур Изатуллоевич         3
# Бобоев Дилшод Рофиевич           3
# Рахматов Илхом Абдулхакович      3
# Халимов Махмадали Муродович      3
# Шафиева Насиба Зиёбоевна         3
# Шеров Нурали Холмуродович        3
# Ятимова Гулчехра Мирзоалиевна    3
# Ёдгоров Саторқул Ҳайдарович      2
# Ёрахмадов Хайрулло               2
# Ёров Курбонали Шомахмадович      2
# Name: party_public_id, dtype: int64
#
# Кластеров с разными именами: 12
#
# Компаний в 2+ странах: 183
# Примеры:
# company_name_norm
# авто комфорт    2
# авто свет       2
# адилет          2
# адина           2
# ажар            2
# азамат          2
# азиз            2
# аида            2
# айару           2
# айбек           2
# Name: country, dtype: int64

# %% [markdown]
# **Вывод:**
# 1. Тезки (одинаковые имена, разные ID):
#    - 169 имен относятся к 2-3 разным людям. Важные отрицательные примеры для обучения
# 2. Компании в разных странах. Может быть просто похожие названия.
#
# Для baseline:
# - Тезки (169) — используем как сложные отрицательные примеры
#
# - 12 кластеров с вариациями — основные положительные примеры вариаций
#
#
# Для ML:
# - Нужно больше тезок (аугментация)
#
# - Нужно больше вариаций имен (аугментация)

# %% [markdown]
# ### 10.2 Edge cases

# %%
# Имена с цифрами
digit_names = df[df['party_name'].str.contains(r'\d', na=False)]['party_name']
print(f"Имен с цифрами: {len(digit_names):,}")
print("Примеры:")
print(digit_names.value_counts().head(10))

# Титулы (г-н, д-р, Mr., Dr.)
title_mask = df['party_name'].str.contains(r'г-н|д-р|mr\.|dr\.|mr |dr ', case=False, na=False)
title_names = df[title_mask]['party_name']
print(f"\nИмен с титулами: {len(title_names):,}")
print("Примеры:")
print(title_names.value_counts().head(10))

# Аббревиатуры (2-4 заглавные буквы)
abbr_mask = df['party_name'].str.match(r'^[A-ZА-ЯЁ]{2,4}$', na=False)
abbr_names = df[abbr_mask]['party_name']
print(f"\nАббревиатур: {len(abbr_names):,}")
print("Примеры:")
print(abbr_names.value_counts().head(10))
# Out:
# Имен с цифрами: 34,089
# Примеры:
# party_name
# Замените на физическое лицо 1     1436
# Замените на физическое лицо 2     1393
# Замените на физическое лицо 3     1280
# Замените на физическое лицо 4     1186
# Замените на физическое лицо 5     1121
# Замените на физическое лицо 6     1065
# Замените на физическое лицо 7     1020
# Замените на физическое лицо 8      976
# Замените на физическое лицо 9      940
# Замените на физическое лицо 10     910
# Name: count, dtype: int64
#
# Имен с титулами: 164
# Примеры:
# party_name
# MEHDİYEV ALEKSANDR KAMİL OĞLU         5
# KOSTİN ALEKSANDR VİKTOROVİÇ           5
# KAZAKOV ALEKSANDR ALEKSANDROVİÇ       4
# Mr.Sinon Vongkusolkit                 4
# QLUXOVA SVETLANA ALEKSANDR QIZI       3
# NAUMOV ALEKSANDR NİKOLAYEVİÇ          3
# MUSTAFAYEV QƏHRƏMAN ALEKSANDR OĞLU    3
# QRİŞİN ALEKSANDR NİKOLAYEVİÇ          3
# Klaus Dr. Meier                       3
# Rolf Gernot Dr. Blanke                3
# Name: count, dtype: int64
#
# Аббревиатур: 537
# Примеры:
# party_name
# ШЦЛ     151
# БГГД    121
# ХЖНХ     65
# СПСУ      8
# КИТО      8
# ЮП        5
# ЦБОН      5
# ГП        4
# АОДЭ      4
# ГОВД      3
# Name: count, dtype: int64

# %% [markdown]
# **Выводы:**
# - "Замените на физическое лицо" — исключить (это не люди)
#
# - Титулы и отчества — можно нормализовать, но не обязательно для baseline
#
# - Аббревиатуры — оставить как есть (их мало)

# %% [markdown]
# ### 10.3 Потенциальные ошибки в данных

# %%
# Все поля пустые (кроме country, relation_kind, relation_role, party_type — они всегда есть)
empty_mask = (df['party_name'].isna() & 
              df['company_name_norm'].isna() & 
              df['party_public_id'].isna() & 
              df['record_id'].isna() & 
              df['ownership_share_pct'].isna() & 
              df['company_public_id'].isna())

print(f"Полностью пустых записей: {empty_mask.sum():,}")

# Противоречивая информация: party_type=individual, но имя как у компании (длинное, с юрформой)
long_names = df[(df['party_type'] == 'individual') & 
                (df['party_name'].str.len() > 100)]
print(f"\nФизлица с длинными именами (>100): {len(long_names):,}")

# party_type=legal_entity, но имя короткое как у человека
short_legal = df[(df['party_type'] == 'legal_entity') & 
                 (df['party_name'].str.len() < 10)]
print(f"Юрлица с короткими именами (<10): {len(short_legal):,}")
print("Примеры:")
print(short_legal['party_name'].value_counts().head(5))

# Полные дубликаты строк
full_dups = df.duplicated().sum()
print(f"\nПолных дубликатов строк: {full_dups:,}")

# Дубликаты без record_id
dup_no_id = df.duplicated(subset=[c for c in df.columns if c != 'record_id']).sum()
print(f"Дубликатов без record_id: {dup_no_id:,}")
# Out:
# Полностью пустых записей: 413,279
#
# Физлица с длинными именами (>100): 6
# Юрлица с короткими именами (<10): 5,980
# Примеры:
# party_name
# Հայգեյթ      720
# ՕՄԻՌԱ ՍՊԸ    312
# Шейрбридж    222
# ШЦЛ          151
# ԴԱՓ          144
# Name: count, dtype: int64
#
# Полных дубликатов строк: 1,068,235
# Дубликатов без record_id: 1,256,912

# %% [markdown]
# **Вывод:**
# - Пустые записи (413K) — исключить из поиска (нет имен)
#
# - Дубликаты — не удаляем, модель сама их найдет
#
# - Противоречия — не критично, оставляем как есть

# %% [markdown]
# ### 10.4 Общий вывод

# %% [markdown]
# Вывод:
# - Пустые записи игнорируем
#
# - Тезки используем как отрицательные примеры
#
# - "Замените на физлицо" исключаем
#
# - Остальное оставляем как есть

# %% [markdown]
# ## 11. Итоговые гипотезы и выводы

# %% [markdown]
# ### 11.1 Ключевые инсайты

# %% [markdown]
# **Топ-5 наблюдений:**
#
# - Размеченных данных 3% — 112K записей с party_public_id, достаточно для обучения
#
# - Вариативность имен крайне низкая — всего 12 кластеров с разными именами из 24,697. Нет транслитерации, нет кросс-страновых связей
#
# - Три алфавита — Armenian (21%), Cyrillic (67%), Latin (11%). Грузинского нет
#
# - Данные по странам разнородны — arm (только shareholder), azb/kaz (только director), mng (самый разнообразный)
#
# - Дубликатов много — 1.27M exact match, 5 групп системных дубликатов, 413K пустых записей

# %% [markdown]
# **Основные паттерны дубликатов:**
#
# - Регистр букв (заглавные vs строчные)
#
# - Кавычки («» vs "" vs без)
#
# - Юридические формы
#
# - Exact match (одна запись из разных источников)

# %% [markdown]
# **Самые сложные случаи:**
#
# - 169 тезок (одинаковые имена, разные люди)
#
# - 12 кластеров с вариациями (все на армянском)
#
# - "Замените на физическое лицо" — технический мусор

# %% [markdown]
# ### 11.2 Гипотезы для модели

# %% [markdown]
# **Самые важные признаки:**
#
# `party_name` — основной (схожесть строк)
#
# `country` — сильный (все дубликаты в одной стране)
#
# `company_public_id` — сильный (99% в разметке)
#
# `party_type` — полезный (ФЛ vs ЮЛ)
#
# **Бесполезные признаки:**
#
# `ownership_share_pct` — 0.04% в разметке
#
# `relation_role` — для большинства стран одно значение
#
# `record_id` — технический
#
# **Транслитерация:**
#
# - Armenian → Latin (нужна)
#
# - Cyrillic → Latin (нужна)
#
# - Latin → нормализация
#
# **Data augmentation необходим:**
#
# - Транслитерация (разные алфавиты)
#
# - Опечатки (1-2 символа)
#
# - Сокращения и перестановки слов
#
# - Вариации юрформ и кавычек

# %% [markdown]
# ### 11.3 План дальнейших действий

# %% [markdown]
# **Чистка датасета**
# - Убрать техничекий мусор
# - Привести имена к базовому формату
# - Транслитерировать в латиницу
# - Разделить данные
# - Исправить даты
#
# **Baseline:**
#
# - Нормализация: lower() + удаление спецсимволов
# - Транслитерация: Armenian→Latin, Cyrillic→Latin
# - Сравнение: exact match + расстояние Левенштейна
# - Порог: подобрать по F1 на валидации
#
# **Train/Test:**
#
# - Положительные пары: ~50,000 из кластеров 2+
# - Отрицательные пары: семплировать 50-100K (включая тезок)
# - Соотношение 1:1 или 1:2
# - Стратификация по странам
#
# **Метрики:**
#
# - Precision, Recall, F1
# - ROC-AUC
# - Confusion matrix
# - Проверка на тезках
#
# **Дальше (после baseline):**
#
# - Feature engineering (n-gram similarity, фонетические признаки)
# - ML-модель (Logistic Regression, XGBoost)
# - Data augmentation (транслитерация, опечатки)
# - Blocking strategy для масштабирования
# - Кластеризация
# - REST API + Docker

# %% [markdown]
# # Общий вывод по результатам EDA

# %% [markdown]
# Был проведен разведывательный анализ данных датасета ClearPic для задачи entity resolution. Датасет содержит 3,733,247 записей о связях компаний с физическими и юридическими лицами из 6 стран (Армения, Азербайджан, Казахстан, Кыргызстан, Монголия, Таджикистан). Данные агрегированы из разных источников: реестров, санкционных списков, судебных решений.
#
# **Ключевые результаты анализа:**
#
# 1. Разметка: 112,141 запись (3%) имеют party_public_id — это "золотой стандарт" для обучения. Из них 53,427 уникальных сущностей, можно создать ~50,000 положительных пар для обучения модели.
#
# 2. Вариативность имен крайне низкая: всего 12 кластеров из 24,697 имеют разные написания имени. Основные паттерны: регистр букв, кавычки, юридические формы. Транслитерация и опечатки в разметке практически отсутствуют. Кросс-страновых связей не обнаружено.
#
# 3. Алфавиты: три основных — Armenian (21%), Cyrillic (67%), Latin (11%). Грузинский не обнаружен. Для baseline необходима транслитерация Armenian→Latin и Cyrillic→Latin.
#
# 4. Качество данных: 413,000 записей полностью пустые, 34,000 записей "Замените на физическое лицо" — технический мусор. Дубликатов exact match — 1.27M. Даты по Таджикистану были в Unix timestamp (исправлены).
#
# 5. Признаки для baseline: party_name (основной), country и company_public_id (сильные контекстные), party_type (полезный). ownership_share_pct и relation_role — бесполезны из-за пропусков или отсутствия вариативности.
#
# **Рекомендации:**
#
# - Baseline строить на нормализации + транслитерации + сравнении строк
#
# - Для ML необходима аугментация данных (транслитерация, опечатки, сокращения)
#
# - При обучении использовать стратификацию по странам и соотношение положительных/отрицательных пар 1:1 или 1:2
#
# - Особое внимание уделить 169 случаям тезок (сложные отрицательные примеры)
